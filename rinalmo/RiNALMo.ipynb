# %%
import torch
from rinalmo.pretrained import get_pretrained_model

DEVICE = "cuda:0"

model, alphabet = get_pretrained_model(model_name="giga-v1")
model = model.to(device=DEVICE)
model.eval()
seqs = ["ACUUUGGCCA", "CCCGGU"]

tokens = torch.tensor(alphabet.batch_tokenize(seqs), dtype=torch.int64, device=DEVICE)
with torch.no_grad(), torch.cuda.amp.autocast():
  outputs = model(tokens)

print(outputs["representation"])
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[15], line 2
#       1 import torch
# ----> 2 from rinalmo.pretrained import get_pretrained_model
#       4 DEVICE = "cuda:0"
#       6 model, alphabet = get_pretrained_model(model_name="giga-v1")
#
# File c:\Users\aquar\PycharmProjects\PTR_ratio_prediction\venv\lib\site-packages\rinalmo\pretrained.py:7
#       4 import json
#       6 from rinalmo.data.alphabet import Alphabet
# ----> 7 from rinalmo.model.model import RiNALMo
#       8 from rinalmo.config import model_config
#      10 DEFAULT_CACHE_DIR = Path.home() / ".cache" / "rinalmo_pretrained"
#
# File c:\Users\aquar\PycharmProjects\PTR_ratio_prediction\venv\lib\site-packages\rinalmo\model\model.py:4
#       1 import torch
#       2 from torch import nn
# ----> 4 from rinalmo.model.modules import Transformer, MaskedLanguageModelHead, TokenDropout
#       6 class RiNALMo(nn.Module):
#       7     def __init__(self, config):
#
# File c:\Users\aquar\PycharmProjects\PTR_ratio_prediction\venv\lib\site-packages\rinalmo\model\modules.py:5
#       2 from torch import nn
#       3 from torch.nn import functional as F
# ----> 5 from rinalmo.model.attention import MultiHeadSelfAttention, FlashMultiHeadSelfAttention
#       7 import torch.utils.checkpoint as checkpoint
#       9 class TokenDropout(nn.Module):
#
# File c:\Users\aquar\PycharmProjects\PTR_ratio_prediction\venv\lib\site-packages\rinalmo\model\attention.py:8
#       4 import math
#       6 from rinalmo.model.rope import RotaryPositionEmbedding
# ----> 8 from flash_attn import flash_attn_varlen_qkvpacked_func, flash_attn_qkvpacked_func
#       9 from flash_attn.layers.rotary import RotaryEmbedding
#      11 from flash_attn.bert_padding import unpad_input, pad_input
#
# ModuleNotFoundError: No module named 'flash_attn'

# %%
# Out:
# c:\Users\aquar\PycharmProjects\PTR_ratio_prediction\venv\Scripts\python.exe

# %%
import sys
print(sys.executable)
# Out:
# c:\Users\aquar\PycharmProjects\PTR_ratio_prediction\venv\Scripts\python.exe
